# %%
import pandas as pd

# %%
kpi_df = pd.read_csv("data/gold/fraud_kpis.csv")

kpi_df
# Out:
#    total_transactions  total_fraud_cases  fraud_rate_percent  \
# 0                1000                245                24.5
#
#    high_risk_transactions  international_transactions  \
# 0                     360                         732
#
#    suspicious_transactions  approved_transactions  declined_transactions  \
# 0                      260                    482                    518
#
#    total_transaction_amount
# 0                2377353.22

# %%
merchant_df = pd.read_csv("data/gold/merchant_fraud_analysis.csv")

merchant_df.head(10)
# Out:
#                         merchant  total_transactions  fraud_cases  \
# 0                     Acosta Inc                   1            0
# 1                 Acosta-Roberts                   1            0
# 2                      Adams PLC                   1            0
# 3                 Adams and Sons                   1            0
# 4    Aguilar, Carney and Hancock                   1            0
# 5    Alexander, Jones and Harris                   1            1
# 6  Alexander, Williams and Rivas                   1            0
# 7               Alexander-Davila                   1            1
# 8                     Allen-Rios                   1            0
# 9                   Anderson Ltd                   1            1
#
#    total_amount  fraud_rate_percent
# 0       3199.95                 0.0
# 1        620.58                 0.0
# 2       2599.20                 0.0
# 3       1426.77                 0.0
# 4       3562.54                 0.0
# 5       4582.50               100.0
# 6       1319.52                 0.0
# 7        112.20               100.0
# 8       2292.21                 0.0
# 9       4998.68               100.0

# %%
country_df = pd.read_csv("data/gold/country_risk_analysis.csv")

country_df
# Out:
#   country  total_transactions  fraud_cases  suspicious_transactions
# 0      CA                 244           62                       88
# 1      NG                 267           63                       84
# 2      UK                 221           60                       88
# 3      US                 268           60                        0

# %%
approval_df = pd.read_csv("data/gold/approval_analysis.csv")

approval_df
# Out:
#      status  total_transactions  total_amount
# 0  approved                 482    1127433.70
# 1  declined                 518    1249919.52
